# %%
from urllib import request
import  urllib.parse
import  urllib.error
from bs4 import BeautifulSoup
import csv
import io
import sys
import time
 
#sys.stdout = io.TextIOWrapper(sys.stdout.buffer,encoding='gb18030')
# resp = request.urlopen('https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?type=S')
# html_data = resp.read().decode('utf-8')
# # print(html_data)
# soup = BeautifulSoup(html_data,'html.parser')
 
 
def get_url_book(url):
    print(url)
    resp = urllib.request.urlopen(url)
    web_data = resp.read().decode('utf-8')
    # print(web_data)
    soup = BeautifulSoup(web_data,'html.parser')
    time.sleep(2)
    return read(soup)
 
def read(soup):
    nowplaying_book = soup.find_all('ul',class_='subject-list')
    # print(nowplaying_book)
    nowplaying_book_list = nowplaying_book[0].find_all('li',class_='subject-item')
    # print(nowplaying_book_list[0])
    book_list = []
    for item in nowplaying_book_list:
        nowplaying_dict = {}
        for tag_info_item in item.find_all('div',class_='info'):
 
            nowplaying_dict['name'] = tag_info_item.find_all('a')[0]['title']
            try:
                nowplaying_dict['dec'] = tag_info_item.find_all('p')[0].string
            except:
                nowplaying_dict['dec'] = ''
 
            nowplaying_dict['pub'] = tag_info_item.find_all('div',class_='pub')[0].string.replace('\n','')
            try:
                nowplaying_dict['rating_nums'] = tag_info_item.find_all('span',class_='rating_nums')[0].string
            except:
                nowplaying_dict['rating_nums'] = '(少于10人评价)'
            nowplaying_dict['people'] = tag_info_item.find_all('span',class_='pl')[0].string.replace('\n','')
            # print(nowplaying_dict)
            book_list.append(nowplaying_dict)
    # print(book_list)
    return book_list
    # print(book_list)
 
list = []
for a in range(3):
    url = 'https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start={}&type=T'.format(a*20)
    data = get_url_book(url)
    list+=data
    print(url)
print(list)
with open("book.csv","w",encoding='gb18030',newline='') as datacsv:
    csvwriter = csv.writer(datacsv,dialect=("excel"))
    csvwriter.writerow(["名称","描述","作者/出版社/价格","评分","评分人数"])
    for item in list:
        csvwriter.writerow([item['name'],item['dec'],item['pub'],item['rating_nums'],item['people']])
 
print("ok")
# Out:
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=0&type=T
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=0&type=T
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=20&type=T
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=20&type=T
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=40&type=T
# https://book.douban.com/tag/%E4%BA%92%E8%81%94%E7%BD%91?start=40&type=T
# [{'name': '浪潮之巅', 'dec': '近一百多年来，总有一些公司很幸运地、有意识或无意识地站在技术革命的浪尖之上。在这十几年间，它们代表着科技的浪潮，直到下一波浪潮的来临。\n从一百年前算起，AT... ', 'pub': '            吴军 / 电子工业出版社 / 2011-8 / 55.00元      ', 'rating_nums': '9.1', 'people': '        (23010人评价)    '}, {'name': '史蒂夫·乔布斯传', 'dec': '这本乔布斯唯一授权的官方传记，在2011年上半年由美国出版商西蒙舒斯特对外发布出版消息以来，备受全球媒体和业界瞩目，这本书的全球出版日期最终确定为2011年... ', 'pub': '            [美] 沃尔特·艾萨克森 / 管延圻、魏群、余倩、赵萌萌、汤崧 / 中信出版社 / 2011-10-24 / 68.00元      ', 'rating_nums': '8.7', 'people': '        (39845人评价)    '}, {'name': '腾讯传', 'dec': '腾讯官方唯一授权的权威传记\n著名财经作家吴晓波倾力之作\n当市值最高的中国互联网公司，遇上中国财经界最冷静的一双眼睛\n读懂腾讯，读懂中国互联网\n.\n内容简介\n... ', 'pub': '            吴晓波 / 浙江大学出版社 / 2017-1-1 / 58.00元      ', 'rating_nums': '7.8', 'people': '        (12212人评价)    '}, {'name': '从0到1', 'dec': '图书简介：\nhttp://v.youku.com/v_show/id_XOTA0NjcyMzE2.html?wm=3333_2001\n硅谷创投教父、PayP... ', 'pub': '            彼得·蒂尔、布莱克·马斯特斯 / 高玉芳 / 中信出版股份有限公司 / 2015-1-1 / CNY 45.00      ', 'rating_nums': '7.6', 'people': '        (21976人评价)    '}, {'name': '增长黑客', 'dec': '脸谱网如何从默默无闻到坐拥二十几亿用户？\n爱彼迎、优步何以在短短时间估值超过百亿美元？\n领英怎样跨步成为全球领先的职业社交平台?\n这些初创公司实现爆发式成长... ', 'pub': '            Sean Ellis / 张溪梦 / 中信出版集团股份有限公司 / 2017-11-1 / CNY 59.00      ', 'rating_nums': '8.4', 'people': '        (1615人评价)    '}, {'name': '失控', 'dec': '《失控》，全名为《失控：机器、社会与经济的新生物学》（Out of Control: The New Biology of Machines, Social... ', 'pub': '            [美] 凯文·凯利 / 东西文库 / 新星出版社 / 2010-12 / 88.00元      ', 'rating_nums': '8.7', 'people': '        (14352人评价)    '}, {'name': '硅谷增长黑客实战笔记', 'dec': '增长黑客这个词源于硅谷，简单说，这是一群以数据驱动营销、以迭代验证策略，通过技术手段实现爆发式增长的新型人才。近年来，互联网公司意识到这一角色可以发挥四两拨... ', 'pub': '            曲卉 / 机械工业出版社 / 2018-4-10 / 65.00元      ', 'rating_nums': '9.1', 'people': '        (778人评价)    '}, {'name': '流量池', 'dec': '移动互联网时代，信息日益冗余，新闻速朽；\n整体流量增长速度放缓，而竞争者数量高速增加；\n流量呈现变少、变贵、欺诈频繁的现状；\n品效合一的营销策略成为共识，而... ', 'pub': '            杨飞 / 中信出版集团 / 2018-4 / 68.00      ', 'rating_nums': '7.6', 'people': '        (2652人评价)    '}, {'name': '黑客与画家', 'dec': '本书是硅谷创业之父Paul Graham 的文集，主要介绍黑客即优秀程序员的爱好和动机，讨论黑客成长、黑客对世界的贡献以及编程语言和黑客工作方法等所有对计算... ', 'pub': '            [美] Paul Graham / 阮一峰 / 人民邮电出版社 / 2011-4 / 49.00元      ', 'rating_nums': '8.7', 'people': '        (16849人评价)    '}, {'name': '运营之光', 'dec': '在互联网行业内，“运营”这个职能发展到一定阶段后，往往更需要有成熟的知识体系和工作方法来给予行业从业者们以指引。\n《运营之光：我的互联网运营方法论与自白》尤... ', 'pub': '            黄有璨 / 电子工业出版社 / 2016-9-1 / 59.00元      ', 'rating_nums': '8.0', 'people': '        (2982人评价)    '}, {'name': '幕后产品', 'dec': '网易云音乐在激烈的竞争中实现了红海突围，获得了很好的口碑，实现了用户量行业前三，这一切离不开背后的核心人物王诗沐。在《幕后产品：打造突破式产品思维》一书中作... ', 'pub': '            王诗沐 / 电子工业出版社 / 2019-4 / 69      ', 'rating_nums': '8.5', 'people': '        (588人评价)    '}, {'name': '启示录', 'dec': '为什么市场上那么多软件产品无人问津，成功的产品凤毛麟角？怎样发掘有价值的产品？拿什么说服开发团队接受你的产品设计？如何将敏捷方法融入产品开发？过去二十多年，... ', 'pub': '            [美] Marty Cagan / 七印部落 / 华中科技大学出版社 / 2011-5 / 36.00元      ', 'rating_nums': '8.5', 'people': '        (6101人评价)    '}, {'name': '重新定义公司', 'dec': '谷歌高管手绘风漫画视频：\nhttp://v.youku.com/v_show/id_XMTMxMzQ3NjMyMA==.html?from=y1.7-1.2... ', 'pub': '            [美]埃里克·施密特 / 靳婷婷、陈序、何晔 / 中信出版社 / 2015-8 / 49.00      ', 'rating_nums': '8.2', 'people': '        (5727人评价)    '}, {'name': '智能商业', 'dec': '《智能商业》由马云作序推荐。《智能商业》是阿里巴巴集团前总参谋长曾鸣，对互联网时代的重要趋势做出革命性解读的作品，披露了其对于未来商业模式的思考和判断。\n2... ', 'pub': '            曾鸣 / 中信出版集团 / 2018-11 / 68.00      ', 'rating_nums': '8.3', 'people': '        (1300人评价)    '}, {'name': '浪潮之巅（第四版）（上下册）', 'dec': '这不只是一部科技产业发展历史集……\n更是在这个智能时代，一部IT人非读不可，而非IT人也应该阅读的作品。\n一个企业的发展与崛起，绝非只是空有领导强人即可达成... ', 'pub': '            吴军 / 人民邮电出版社 / 2019-6 / 139.00元      ', 'rating_nums': '9.6', 'people': '        (81人评价)    '}, {'name': '大数据时代', 'dec': '《大数据时代》是国外大数据研究的先河之作，本书作者维克托•迈尔•舍恩伯格被誉为“大数据商业应用第一人”，拥有在哈佛大学、牛津大学、耶鲁大学和新加坡国立大学等... ', 'pub': '            [英] 维克托•迈尔•舍恩伯格（Viktor Mayer-Schönberger） / 周涛 / 浙江人民出版社 / 2012-12 / 49.90元      ', 'rating_nums': '7.5', 'people': '        (15551人评价)    '}, {'name': '智能时代', 'dec': '大数据和机器智能的出现，对我们的技术发展、商业和社会都会产生重大的影响。作者吴军在《智能时代：大数据与智能革命重新定义未来》中指出，首先，我们在过去认为非常... ', 'pub': '      ...
# ok
